# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
folder = 'D:/'

# %%
FDF = pd.read_excel(folder +'Finance HLOC.xlsx')
FDF
# Out:
#          Company Name        Date         Open         High          Low  \
# 0        Bajaj Finance 2018-04-02  1769.000000  1825.000000  1769.000000
# 1        Bajaj Finance 2018-04-03  1820.000000  1840.000000  1801.599976
# 2        Bajaj Finance 2018-04-04  1840.000000  1869.599976  1836.699951
# 3        Bajaj Finance 2018-04-05  1866.000000  1922.099976  1866.000000
# 4        Bajaj Finance 2018-04-06  1919.000000  1943.500000  1908.849976
# ...                ...        ...          ...          ...          ...
# 6180  Sundaram Finance 2023-03-23  2270.500000  2303.300049  2240.100098
# 6181  Sundaram Finance 2023-03-24  2279.850098  2303.300049  2267.000000
# 6182  Sundaram Finance 2023-03-27  2289.800049  2294.350098  2232.600098
# 6183  Sundaram Finance 2023-03-28  2252.850098  2275.000000  2217.000000
# 6184  Sundaram Finance 2023-03-29  2250.000000  2295.000000  2233.000000
#
#             Close    Adj Close   Volume  Daily Returns  Daily Returns in %
# ...

# %%
FDF.isnull()
FDF
# Out:
#          Company Name        Date         Open         High          Low  \
# 0        Bajaj Finance 2018-04-02  1769.000000  1825.000000  1769.000000
# 1        Bajaj Finance 2018-04-03  1820.000000  1840.000000  1801.599976
# 2        Bajaj Finance 2018-04-04  1840.000000  1869.599976  1836.699951
# 3        Bajaj Finance 2018-04-05  1866.000000  1922.099976  1866.000000
# 4        Bajaj Finance 2018-04-06  1919.000000  1943.500000  1908.849976
# ...                ...        ...          ...          ...          ...
# 6180  Sundaram Finance 2023-03-23  2270.500000  2303.300049  2240.100098
# 6181  Sundaram Finance 2023-03-24  2279.850098  2303.300049  2267.000000
# 6182  Sundaram Finance 2023-03-27  2289.800049  2294.350098  2232.600098
# 6183  Sundaram Finance 2023-03-28  2252.850098  2275.000000  2217.000000
# 6184  Sundaram Finance 2023-03-29  2250.000000  2295.000000  2233.000000
#
#             Close    Adj Close   Volume  Daily Returns  Daily Returns in %
# ...

# %%
FDF.max()
# Out:
# Company Name             Sundaram Finance
# Date                  2023-03-29 00:00:00
# Open                               8050.0
# High                               8050.0
# Low                           7861.299805
# Close                         7929.299805
# Adj Close                     7833.144531
# Volume                          208218494
# Daily Returns                  554.600098
# Daily Returns in %              23.260867
# dtype: object

# %%
FDF.min()
# Out:
# Company Name                Bajaj Finance
# Date                  2018-04-02 00:00:00
# Open                            43.715359
# High                            47.435814
# Low                             42.692234
# Close                           45.157036
# Adj Close                       43.419827
# Volume                                963
# Daily Returns                 -433.700195
# Daily Returns in %             -20.714285
# dtype: object

# %%
# From the above observation we can say Sundaram Finanace and Bajaj Finanace are highly volatile stocks

# %%
# Note: As analysing stocks data considering market behaviour and stock price fluctuation we will not remove outliers regorously

# %%
fl = 'D:/Finanace XL/'

# %%
data_Bajaj_f = pd.read_excel(fl + 'BAJFINANCE.NS.xlsx')  
data_Bajaj_f.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1237.000000  1237.000000  1237.000000  1237.000000  1237.000000
# mean   4632.049801  4695.505177  4560.405415  4627.251738  4567.131085
# std    1851.684656  1866.860223  1833.944151  1847.759408  1834.249968
# min    1769.000000  1825.000000  1769.000000  1818.599976  1783.338989
# 25%    2930.000000  2994.000000  2891.050049  2932.600098  2882.400879
# 50%    4247.000000  4295.750000  4218.600098  4252.649902  4184.683594
# 75%    6220.000000  6299.500000  6151.250000  6202.399902  6148.820313
# max    8050.000000  8050.000000  7861.299805  7929.299805  7833.144531
#
#              Volume
# count  1.237000e+03
# mean   2.644616e+06
# std    3.178309e+06
# min    9.403300e+04
# 25%    9.591730e+05
# 50%    1.455320e+06
# 75%    2.778837e+06
# max    2.596005e+07

# %%
ltf = 'D:/Finanace XL/'

# %%
data_Ltf_f = pd.read_excel(fl + 'L&TFH.NS.xlsx',usecols=['Date','Open','High',"Low","Close","Adj Close",'Volume'])  
data_Ltf_f.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1237.000000  1230.000000  1230.000000  1230.000000  1230.000000
# mean     99.406683   100.675508    96.973503    98.699735    95.411043
# std      32.917960    32.796332    31.863557    32.300903    30.039767
# min      43.715359    47.435814    42.692234    45.157036    43.419827
# 25%      77.500000    78.412501    76.000000    77.500000    75.856613
# 50%      90.000000    91.424999    88.550003    89.900002    87.938202
# 75%     120.349998   122.199997   117.637501   119.887501   114.554234
# max     188.500000   186.449997   180.199997   182.649994   173.337967
#
#              Volume
# count  1.230000e+03
# mean   1.086245e+07
# std    9.332206e+06
# min    9.928050e+05
# 25%    5.220763e+06
# 50%    8.119109e+06
# 75%    1.342469e+07
# max    1.111402e+08

# %%
high_mean = data_Ltf_f['Close'].mean()
high_mean
# Out:
# 98.69973476341463

# %%
M_MF = 'D:/Finanace XL/'

# %%
data_MF_F = pd.read_excel(M_MF + 'M&MFIN.NS.xlsx')  
data_MF_F.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1237.000000  1237.000000  1237.000000  1237.000000  1237.000000
# mean    260.418920   265.271889   255.341973   260.062580   240.429883
# std     124.127932   125.918355   122.050844   123.932484   112.634844
# min      79.260658    81.638474    76.456047    77.766899    71.572983
# 25%     161.300003   164.199997   158.550003   161.449997   148.821045
# 50%     207.850006   209.949997   202.649994   206.399994   194.654617
# 75%     380.149994   388.500000   372.149994   379.700012   348.071899
# max     532.500000   534.000000   516.650024   528.150024   481.676575
#
#              Volume
# count  1.237000e+03
# mean   6.285655e+06
# std    9.629773e+06
# min    6.060900e+04
# 25%    1.767425e+06
# 50%    3.497075e+06
# 75%    7.357962e+06
# max    2.082185e+08

# %%
SHRIRAM_F = 'D:/Finanace XL/'

# %%
data_SHRIRAM_F = pd.read_excel(SHRIRAM_F + 'SHRIRAMFIN.NS.xlsx')  
data_SHRIRAM_F.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1113.000000  1113.000000  1113.000000  1113.000000  1113.000000
# mean   1221.806719  1243.963812  1197.996402  1220.170487  1131.974109
# std     181.964831   182.272395   179.985233   180.974710   171.827744
# min     642.098694   683.995850   634.596130   677.467712   622.295166
# 25%    1107.949951  1128.000000  1084.650024  1108.750000  1022.958191
# 50%    1223.000000  1246.099976  1203.000000  1220.050049  1139.809082
# 75%    1346.000000  1366.750000  1323.000000  1342.650024  1262.017944
# max    1676.699951  1696.400024  1621.050049  1664.699951  1559.292236
#
#              Volume
# count  1.113000e+03
# mean   1.707178e+06
# std    1.976442e+06
# min    6.887900e+04
# 25%    7.608250e+05
# 50%    1.131123e+06
# 75%    1.906513e+06
# max    3.211927e+07

# %%
SD_F = 'D:/Finanace XL/'

# %%
data_SUNDARAM_F = pd.read_excel(SD_F +'SUNDARMFIN.NS.xlsx')   
  
data_SUNDARAM_F.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1237.000000  1237.000000  1237.000000  1237.000000  1237.000000
# mean   1848.215440  1875.248663  1816.278664  1846.479790  1794.480615
# std     427.654576   431.311989   421.162744   427.664032   432.356519
# min    1050.099976  1112.449951   982.049988  1047.900024  1012.512390
# 25%    1500.500000  1518.949951  1477.449951  1497.699951  1432.293823
# 50%    1717.750000  1744.599976  1683.949951  1711.900024  1641.098389
# 75%    2271.300049  2300.000000  2236.649902  2269.250000  2243.276123
# max    2752.000000  2868.000000  2700.050049  2820.149902  2748.854736
#
#              Volume
# count  1.237000e+03
# mean   5.046408e+04
# std    1.368165e+05
# min    9.630000e+02
# 25%    1.162200e+04
# 50%    2.407000e+04
# 75%    4.929800e+04
# max    3.688817e+06

# %% [markdown]
# # Correlation between sectors leading company and other large cap and mid cap companies

# %%
BF_to_TF = data_Bajaj_f['Close'].corr(data_Ltf_f['Close']) # Correlation with Bajaj finance ltd which is leading company
BF_to_TF # Observation: There is STRONG NEGATIVE correlation betwwen Bajajfinanace and L&Tf

BF_to_MF = data_Bajaj_f['Close'].corr(data_MF_F['Close'])
BF_to_MF # There is nutral negative correlation between Bajaj finance and M&M Finance

BF_to_SHRIRAM_F = data_Bajaj_f['Close'].corr(data_SHRIRAM_F['Close'])
BF_to_SHRIRAM_F # As both are large cap cmpn there is strong correlation between Bajaj finance and SHRIRAM Finance

BF_to_SUNDARAM_F = data_Bajaj_f['Close'].corr(data_SUNDARAM_F['Close'])
BF_to_SUNDARAM_F # As both are large cap cmpn there is strong correlation between Bajaj finance and SUNDARAM Finance

print(BF_to_TF,BF_to_MF,BF_to_SHRIRAM_F,BF_to_SUNDARAM_F)
# Out:
# -0.8082696522460198 -0.558649749016895 0.8394370186618628 0.8248446158895955

# %%
BNIFTY_CL_D = 'D:/'

# %%
BNCLD = pd.read_excel('Banknifty.Closing.Data.xlsx')
BNCLD.describe()
# Out:
#        Unnamed: 0  Unnamed: 1  Banknifty closing
# count         0.0         0.0        1231.000000
# mean          NaN         NaN       31435.371820
# std           NaN         NaN        6207.339400
# min           NaN         NaN       16917.650391
# 25%           NaN         NaN       26825.750000
# 50%           NaN         NaN       31160.349609
# 75%           NaN         NaN       36166.550782
# max           NaN         NaN       44049.101563

# %% [markdown]
# # Correlation between banknifty and Finance sector's leading company Bajaj Finance ltd.

# %%
BNCLD_crr = data_Bajaj_f['Close'].corr(BNCLD['Banknifty closing'])
BNCLD_crr # Observation: Very high correlation between Banknifty and Leading company Bajaj Finance ltd.
# Out:
# 0.885132834129037

# %% [markdown]
# # Volatility visualization

# %%
fc = "D:/"

# %%
Fin_Close = pd.read_excel(fc + 'Fin.Close.xlsx')
Fin_Close
# Out:
#            Date      Bajaj_f       L&t_f       M&m_f   Shriram_f   Sundaram_f
# 0    2018-04-02  1818.599976  182.649994  471.450012  677.467712  1699.349976
# 1    2018-04-03  1834.250000  181.750000  473.750000  678.149719  1694.650024
# 2    2018-04-04  1850.199951  181.399994  465.799988  679.000000  1722.199951
# 3    2018-04-05  1915.599976  180.800003  486.649994  679.270264  1704.150024
# 4    2018-04-06  1937.599976  180.750000  496.200012  679.450012  1707.500000
# ...         ...          ...         ...         ...         ...          ...
# 1232 2023-03-23  5833.049805         NaN  227.699997         NaN  2274.149902
# 1233 2023-03-24  5649.250000         NaN  220.500000         NaN  2282.949951
# 1234 2023-03-27  5593.049805         NaN  218.149994         NaN  2256.899902
# 1235 2023-03-28  5534.450195         NaN  221.399994         NaN  2256.750000
# 1236 2023-03-29  5625.200195         NaN  226.699997         NaN  2277.399902
#
# [1237 rows x 6 columns]

# %%
 Fin = Fin_Close
Fin.plot()

plt.legend()

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.15)
plt.show()

# %%
plt.figure(figsize = (50,20))
sns.pairplot(Fin, y_vars = 'Date', x_vars = ['Bajaj_f','L&t_f','M&m_f','Shriram_f','Sundaram_f'])
plt.show()

# %%
FMA = FDF['Close'].to_frame()

# Calculate 50 day simple moving average(SMA)
FMA ['SMA 50'] = FMA ['Close'].rolling(50).mean()

FMA.dropna(inplace = True)

FMA
# Out:
#             Close       SMA 50
# 49    2250.300049  1976.310994
# 50    2261.250000  1985.163994
# 51    2231.050049  1993.099995
# 52    2243.250000  2000.960996
# 53    2283.600098  2008.320999
# ...           ...          ...
# 6180  2274.149902  2295.588994
# 6181  2282.949951  2295.218994
# 6182  2256.899902  2294.313994
# 6183  2256.750000  2293.015996
# 6184  2277.399902  2292.261992
#
# [6136 rows x 2 columns]

# %%
FMA [['Close','SMA 50']].plot(label= 'FMA', figsize = (16,8)) # 50 sma for all 5 stocks data
# Out:
# <Axes: >

# %% [markdown]
# # Statstical insights

# %%
selected_column = 'Close'

# Calculate basic statistics for the selected column
summary_stats = data_Bajaj_f[selected_column].describe()

print(summary_stats)
# Out:
# count    1237.000000
# mean     4627.251738
# std      1847.759408
# min      1818.599976
# 25%      2932.600098
# 50%      4252.649902
# 75%      6202.399902
# max      7929.299805
# Name: Close, dtype: float64

# %% [markdown]
# # Basic Statistics for Banknifty index closing price

# %%
selected_column = 'Banknifty closing'

# Calculate basic statistics for the selected column (Considerd last 5 years daily closing data)
summary_stats = BNCLD[selected_column].describe()

print(summary_stats)
# Out:
# count     1231.000000
# mean     31435.371820
# std       6207.339400
# min      16917.650391
# 25%      26825.750000
# 50%      31160.349609
# 75%      36166.550782
# max      44049.101563
# Name: Banknifty closing, dtype: float64

# %%
FMA [['Close','SMA 50']].plot(label= 'FMA', figsize = (16,8)) # 50 sma for all 5 stocks data
# Out:
# <Axes: >

# %% [markdown]
# # Seasonal trend analysis for Banknifty index

# %%
# !pip install pillow
# or
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
import IPython.display as display

# Load the image
image_path = 'C:/Users/bhush/OneDrive/Pictures/Screenshots/Screenshot (76).png'
img = Image.open(image_path)

# Display the image
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %% [markdown]
# # Observation: Above is the banknifty weekly chart and in every september month of the years nifty moved upword drasticly
# # its good for swing trading in the stocks which follows banknifty , as well banknifty index for options trading

# %% [markdown]
# # Analysis for Power Generation,Distribution sector(Large cap , mid cap)

# %%
pfile = 'D:/'

# %%
pcdf = pd.read_excel(pfile + 'Power.Close.xlsx')
pcdf
# Out:
#            Date       Jsw_p  Nlcindia_p      Ntpc_p  Powergrid_p  Torntpower_p
# 0    2018-04-02  296.549988   85.699997  142.000000   109.631279    234.100006
# 1    2018-04-03  303.049988   86.050003  141.125000   111.684402    239.850006
# 2    2018-04-04  295.850006   85.550003  138.791672   110.278152    234.600006
# 3    2018-04-05  308.399994   88.099998  140.791672   110.390656    242.500000
# 4    2018-04-06  308.200012   88.500000  141.208328   110.221901    247.899994
# ...         ...         ...         ...         ...          ...           ...
# 1232 2023-03-23  667.799988   76.199997  174.600006   166.612503    515.500000
# 1233 2023-03-24  657.799988   73.650002  172.699997   166.800003    502.899994
# 1234 2023-03-27  658.849976   71.900002  171.250000   165.074997    487.200012
# 1235 2023-03-28  660.000000   72.099998  172.000000   166.574997    511.350006
# 1236 2023-03-29  678.900024   75.699997  174.000000   166.837494    530.250000
#
# [1237 rows x 6 columns]

# %%
pcdf.describe()
# Out:
#              Jsw_p   Nlcindia_p       Ntpc_p  Powergrid_p  Torntpower_p
# count  1237.000000  1237.000000  1237.000000  1237.000000   1237.000000
# mean    443.487308    64.066289   126.287685   125.231972    370.346403
# std     198.547361    12.241406    24.131287    25.857267    112.174140
# min     140.699997    39.299999    76.400002    81.084396    214.000000
# 25%     277.000000    54.250000   111.041664   105.750023    271.299988
# 50%     353.500000    63.549999   125.500000   114.018776    324.450012
# 75%     667.000000    73.650002   140.416672   153.637497    480.850006
# max     775.299988    93.449997   181.800003   183.862503    598.599976

# %%
Nf = 'D:/'

# %%
Niftyc = pd.read_excel (Nf + 'Nifty50.Close.xlsx')
Niftyc
# Out:
#            Date         Close
# 0    2018-04-02  10211.799805
# 1    2018-04-03  10245.000000
# 2    2018-04-04  10128.400391
# 3    2018-04-05  10325.150391
# 4    2018-04-06  10331.599609
# ...         ...           ...
# 1232 2023-03-23  17076.900391
# 1233 2023-03-24  16945.050781
# 1234 2023-03-27  16985.699219
# 1235 2023-03-28  16951.699219
# 1236 2023-03-29  17080.699219
#
# [1237 rows x 2 columns]

# %% [markdown]
# # Correlation analysis between Nifty50 and Power sector's stocks

# %%
Nf_pw = Niftyc['Close'].corr(pcdf['Jsw_p']) 
Nf_pw # Observation: Very strong relation between Nifty50 and JSW POWER stock price
# Out:
# 0.9414096251250326

# %%
Nf_pw = Niftyc['Close'].corr(pcdf['Nlcindia_p'])
Nf_pw
# Out:
# 0.2896172572664312

# %%
Nf_pw = Niftyc['Close'].corr(pcdf['Ntpc_p'])
Nf_pw
# Out:
# 0.590379594829439

# %%
Nf_pw = Niftyc['Close'].corr(pcdf['Powergrid_p'])
Nf_pw
# Out:
# 0.9039271378616931

# %%
Nf_pw = Niftyc['Close'].corr(pcdf['Torntpower_p'])
Nf_pw # Observation: Very strong relation between Nifty50 and TORNTPOWER stock price
# Out:
# 0.9321250087820083

# %%
pcdf.max()
# Out:
# Date            2023-03-29 00:00:00
# Jsw_p                    775.299988
# Nlcindia_p                93.449997
# Ntpc_p                   181.800003
# Powergrid_p              183.862503
# Torntpower_p             598.599976
# dtype: object

# %%
pcdf.min()
# Out:
# Date            2018-04-02 00:00:00
# Jsw_p                    140.699997
# Nlcindia_p                39.299999
# Ntpc_p                    76.400002
# Powergrid_p               81.084396
# Torntpower_p                  214.0
# dtype: object

# %%
pw = pcdf
pw.drop('Date', axis=1)
pw.plot()

plt.legend()

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.15)
plt.show()

# %%
Niftyc['Close'] = Niftyc ['Close'].fillna(Niftyc['Close'].mode()[0])
Niftyma = Niftyc['Close'].to_frame()

# Calculate 50 day simple moving average(SMA)
Niftyma ['SMA 50'] = Niftyc ['Close'].rolling(50).mean()

Niftyc.dropna(inplace = True)

Niftyma
Niftyma['SMA 50'] = Niftyma ['SMA 50'].fillna(Niftyma['SMA 50'].mode()[0])

# %%
Niftyma [['Close','SMA 50']].plot(label= 'FMA', figsize = (16,8)) # 50 sma for Nifty50
# Out:
# <Axes: >

# %%
plt.figure(figsize = (50,20))
sns.pairplot(pcdf, y_vars = 'Date', x_vars = ['Jsw_p','Nlcindia_p','Ntpc_p','Powergrid_p','Torntpower_p'])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(pw.corr(), ax = ax, annot=True, linewidth = 0.5 , fmt='.2f', cmap='magma')
plt.show()
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_9212\2436912389.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(pw.corr(), ax = ax, annot=True, linewidth = 0.5 , fmt='.2f', cmap='magma')

# %%
pw.skew()
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_9212\1510795206.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pw.skew()
# Jsw_p           0.290289
# Nlcindia_p      0.218406
# Ntpc_p          0.193911
# Powergrid_p     0.574688
# Torntpower_p    0.368793
# dtype: float64

# %%
pw.kurtosis()
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_9212\3212434906.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pw.kurtosis()
# Jsw_p          -1.575887
# Nlcindia_p     -0.865610
# Ntpc_p         -0.594984
# Powergrid_p    -1.070473
# Torntpower_p   -1.382660
# dtype: float64
